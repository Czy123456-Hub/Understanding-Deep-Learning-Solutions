# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-2j0vz5xo
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-2j0vz5xo
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.32.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (1.15.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.6.15)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=12658a0053ebda25471bd1b3c5fdfce2af6069bb9fb00f4ad049a62e1a964073
#   Stored in directory: /tmp/pip-ephem-wheel-cache-3ynd842g/wheels/d6/38/42/3d2112bc7d915f6195254ac85eb761d922d1b18f52817aa8e2
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.302442, train error 89.68,  test loss 2.302632, test error 89.93
# Epoch   100, train loss 1.912178, train error 72.35,  test loss 1.757956, test error 69.68
# Epoch   200, train loss 1.904817, train error 71.25,  test loss 1.745200, test error 69.22
# Epoch   300, train loss 1.904062, train error 71.35,  test loss 1.740450, test error 69.30
# Epoch   400, train loss 1.903124, train error 70.43,  test loss 1.741634, test error 69.78
# Epoch   500, train loss 1.904090, train error 70.70,  test loss 1.741469, test error 69.43
# Epoch   600, train loss 1.902839, train error 72.15,  test loss 1.733094, test error 69.65
# Epoch   700, train loss 1.902650, train error 71.35,  test loss 1.740117, test error 69.22
# Epoch   800, train loss 1.902719, train error 70.43,  test loss 1.738042, test error 69.90
# Epoch   900, train loss 1.903053, train error 71.15,  test loss 1.737594, test error 69.72
# Training model with   4 hidden variables
# Epoch     0, train loss 2.258418, train error 85.40,  test loss 2.248134, test error 84.68
# Epoch   100, train loss 1.757138, train error 64.45,  test loss 1.585434, test error 61.38
# Epoch   200, train loss 1.729023, train error 64.30,  test loss 1.559933, test error 61.50
# Epoch   300, train loss 1.723917, train error 64.15,  test loss 1.560751, test error 61.45
# Epoch   400, train loss 1.723310, train error 63.67,  test loss 1.557272, test error 61.72
# Epoch   500, train loss 1.719821, train error 63.67,  test loss 1.561875, test error 60.85
# Epoch   600, train loss 1.719942, train error 63.53,  test loss 1.561576, test error 60.80
# Epoch   700, train loss 1.717774, train error 63.28,  test loss 1.555711, test error 60.90
# Epoch   800, train loss 1.720135, train error 63.55,  test loss 1.553294, test error 60.75
# Epoch   900, train loss 1.719872, train error 64.00,  test loss 1.550846, test error 61.28
# Training model with   6 hidden variables
# Epoch     0, train loss 2.304125, train error 88.50,  test loss 2.308586, test error 88.68
# Epoch   100, train loss 1.662246, train error 58.45,  test loss 1.491558, test error 58.40
# Epoch   200, train loss 1.647956, train error 58.55,  test loss 1.508467, test error 57.95
# Epoch   300, train loss 1.631101, train error 59.03,  test loss 1.493184, test error 58.05
# Epoch   400, train loss 1.620940, train error 58.80,  test loss 1.497361, test error 57.85
# Epoch   500, train loss 1.621074, train error 58.53,  test loss 1.499684, test error 57.92
# Epoch   600, train loss 1.623890, train error 58.17,  test loss 1.509591, test error 58.83
# Epoch   700, train loss 1.610915, train error 57.92,  test loss 1.500562, test error 57.58
# Epoch   800, train loss 1.610758, train error 57.92,  test loss 1.501274, test error 57.53
# Epoch   900, train loss 1.612441, train error 58.08,  test loss 1.518736, test error 58.53
# Training model with   8 hidden variables
# Epoch     0, train loss 2.203961, train error 81.12,  test loss 2.180598, test error 81.45
# Epoch   100, train loss 1.566260, train error 54.20,  test loss 1.398861, test error 52.47
# Epoch   200, train loss 1.464545, train error 49.90,  test loss 1.285254, test error 47.50
# Epoch   300, train loss 1.435354, train error 49.50,  test loss 1.267834, test error 47.17
# Epoch   400, train loss 1.429442, train error 48.60,  test loss 1.277343, test error 47.35
# Epoch   500, train loss 1.415876, train error 48.10,  test loss 1.278943, test error 46.75
# Epoch   600, train loss 1.412142, train error 47.72,  test loss 1.285553, test error 47.33
# Epoch   700, train loss 1.417577, train error 47.92,  test loss 1.290456, test error 47.60
# Epoch   800, train loss 1.407286, train error 47.83,  test loss 1.290779, test error 46.95
# Epoch   900, train loss 1.410843, train error 47.78,  test loss 1.294068, test error 47.30
# Training model with  10 hidden variables
# Epoch     0, train loss 2.212565, train error 82.53,  test loss 2.184030, test error 81.90
# Epoch   100, train loss 1.613362, train error 56.58,  test loss 1.470627, test error 56.53
# Epoch   200, train loss 1.566211, train error 55.35,  test loss 1.470300, test error 55.60
# Epoch   300, train loss 1.535963, train error 54.10,  test loss 1.482732, test error 56.60
# Epoch   400, train loss 1.519137, train error 53.75,  test loss 1.484626, test error 55.75
# Epoch   500, train loss 1.505150, train error 53.35,  test loss 1.504338, test error 56.83
# Epoch   600, train loss 1.493778, train error 52.67,  test loss 1.514781, test error 56.30
# Epoch   700, train loss 1.487942, train error 52.65,  test loss 1.514279, test error 55.62
# Epoch   800, train loss 1.484621, train error 52.15,  test loss 1.529960, test error 56.15
# Epoch   900, train loss 1.479822, train error 52.38,  test loss 1.542484, test error 56.08
# Training model with  14 hidden variables
# Epoch     0, train loss 2.285742, train error 85.75,  test loss 2.277561, test error 84.95
# Epoch   100, train loss 1.489039, train error 52.10,  test loss 1.414736, test error 53.75
# Epoch   200, train loss 1.384544, train error 47.22,  test loss 1.375179, test error 51.00
# Epoch   300, train loss 1.344964, train error 46.10,  test loss 1.417528, test error 51.95
# Epoch   400, train loss 1.326290, train error 45.10,  test loss 1.464779, test error 53.25
# Epoch   500, train loss 1.317103, train error 45.20,  test loss 1.482054, test error 53.80
# Epoch   600, train loss 1.303189, train error 44.15,  test loss 1.483793, test error 53.60
# Epoch   700, train loss 1.293100, train error 44.38,  test loss 1.498603, test error 53.50
# Epoch   800, train loss 1.291488, train error 44.00,  test loss 1.517298, test error 54.03
# Epoch   900, train loss 1.289669, train error 43.60,  test loss 1.534744, test error 54.53
# Training model with  18 hidden variables
# Epoch     0, train loss 2.143466, train error 80.65,  test loss 2.104290, test error 79.65
# Epoch   100, train loss 1.354530, train error 45.47,  test loss 1.324226, test error 49.72
# Epoch   200, train loss 1.258308, train error 42.25,  test loss 1.343535, test error 49.15
# Epoch   300, train loss 1.224301, train error 41.97,  test loss 1.397631, test error 50.08
# Epoch   400, train loss 1.198477, train error 40.42,  test loss 1.426592, test error 49.70
# Epoch   500, train loss 1.186022, train error 40.10,  test loss 1.458023, test error 50.08
# Epoch   600, train loss 1.170125, train error 38.80,  test loss 1.476985, test error 50.03
# Epoch   700, train loss 1.147975, train error 38.80,  test loss 1.519564, test error 50.08
# Epoch   800, train loss 1.139260, train error 38.38,  test loss 1.547743, test error 49.62
# Epoch   900, train loss 1.128554, train error 37.90,  test loss 1.576359, test error 50.30
# Training model with  22 hidden variables
# Epoch     0, train loss 2.120562, train error 78.20,  test loss 2.076973, test error 75.88
# Epoch   100, train loss 1.309195, train error 44.17,  test loss 1.366602, test error 51.50
# Epoch   200, train loss 1.162730, train error 39.10,  test loss 1.411864, test error 51.25
# Epoch   300, train loss 1.089480, train error 37.03,  test loss 1.493417, test error 51.00
# Epoch   400, train loss 1.055701, train error 36.12,  test loss 1.563663, test error 51.90
# Epoch   500, train loss 1.017057, train error 34.70,  test loss 1.631059, test error 51.88
# Epoch   600, train loss 1.002898, train error 34.05,  test loss 1.688422, test error 51.75
# Epoch   700, train loss 0.978922, train error 34.05,  test loss 1.764537, test error 52.12
# Epoch   800, train loss 0.967988, train error 32.85,  test loss 1.831518, test error 52.88
# Epoch   900, train loss 0.953860, train error 32.97,  test loss 1.873834, test error 53.35
# Training model with  26 hidden variables
# Epoch     0, train loss 2.153822, train error 79.93,  test loss 2.139139, test error 79.62
# Epoch   100, train loss 1.169933, train error 39.35,  test loss 1.352838, test error 50.33
# Epoch   200, train loss 1.025425, train error 34.88,  test loss 1.485868, test error 51.28
# Epoch   300, train loss 0.961693, train error 33.45,  test loss 1.628689, test error 53.30
# Epoch   400, train loss 0.914742, train error 31.43,  test loss 1.740552, test error 53.50
# Epoch   500, train loss 0.885146, train error 30.20,  test loss 1.817438, test error 53.90
# Epoch   600, train loss 0.868369, train error 29.20,  test loss 1.922793, test error 54.58
# Epoch   700, train loss 0.868098, train error 30.47,  test loss 1.986140, test error 55.15
# Epoch   800, train loss 0.825328, train error 28.30,  test loss 2.033352, test error 54.75
# Epoch   900, train loss 0.828669, train error 28.38,  test loss 2.101074, test error 54.35
# Training model with  30 hidden variables
# Epoch     0, train loss 2.158091, train error 82.05,  test loss 2.136320, test error 81.40
# Epoch   100, train loss 1.146288, train error 37.03,  test loss 1.386639, test error 50.83
# Epoch   200, train loss 0.950404, train error 30.95,  test loss 1.573963, test error 52.10
# Epoch   300, train loss 0.869533, train error 29.40,  test loss 1.778091, test error 53.88
# Epoch   400, train loss 0.817606, train error 27.10,  test loss 1.925343, test error 54.55
# Epoch   500, train loss 0.791728, train error 26.93,  test loss 2.072402, test error 55.00
# Epoch   600, train loss 0.753327, train error 25.62,  test loss 2.220489, test error 54.92
# Epoch   700, train loss 0.737029, train error 25.53,  test loss 2.387733, test error 56.55
# Epoch   800, train loss 0.705200, train error 24.75,  test loss 2.524197, test error 57.53
# Epoch   900, train loss 0.707534, train error 24.50,  test loss 2.666571, test error 57.88
# Training model with  35 hidden variables
# Epoch     0, train loss 2.154992, train error 78.32,  test loss 2.146781, test error 79.18
# Epoch   100, train loss 1.010994, train error 33.68,  test loss 1.405729, test error 50.47
# Epoch   200, train loss 0.786542, train error 26.50,  test loss 1.738063, test error 52.58
# Epoch   300, train loss 0.698500, train error 24.18,  test loss 2.143525, test error 54.75
# Epoch   400, train loss 0.584650, train error 19.53,  test loss 2.509307, test error 56.90
# Epoch   500, train loss 0.558559, train error 19.18,  test loss 2.832711, test error 56.67
# Epoch   600, train loss 0.519859, train error 17.40,  test loss 3.213808, test error 57.30
# Epoch   700, train loss 0.496731, train error 17.18,  test loss 3.448443, test error 57.75
# Epoch   800, train loss 0.480530, train error 17.03,  test loss 3.730229, test error 57.85
# Epoch   900, train loss 0.451005, train error 15.88,  test loss 4.031046, test error 57.50
# Training model with  40 hidden variables
# Epoch     0, train loss 2.043396, train error 77.10,  test loss 1.991037, test error 76.75
# Epoch   100, train loss 0.897883, train error 29.32,  test loss 1.414866, test error 48.85
# Epoch   200, train loss 0.644154, train error 20.93,  test loss 1.881956, test error 50.97
# Epoch   300, train loss 0.520661, train error 17.43,  test loss 2.435630, test error 52.47
# Epoch   400, train loss 0.442686, train error 15.18,  test loss 3.071187, test error 54.60
# Epoch   500, train loss 0.379295, train error 13.78,  test loss 3.723817, test error 55.12
# Epoch   600, train loss 0.327804, train error 11.55,  test loss 4.354062, test error 55.90
# Epoch   700, train loss 0.365062, train error 13.72,  test loss 5.057427, test error 57.20
# Epoch   800, train loss 0.297949, train error 10.78,  test loss 5.681561, test error 56.62
# Epoch   900, train loss 0.293766, train error 10.38,  test loss 6.270238, test error 57.55
# Training model with  45 hidden variables
# Epoch     0, train loss 2.090798, train error 77.53,  test loss 2.047367, test error 78.00
# Epoch   100, train loss 0.787207, train error 25.03,  test loss 1.495433, test error 50.33
# Epoch   200, train loss 0.466008, train error 13.85,  test loss 2.289412, test error 52.97
# Epoch   300, train loss 0.317503, train error 9.35,  test loss 3.449167, test error 55.42
# Epoch   400, train loss 0.202190, train error 5.43,  test loss 4.701146, test error 57.30
# Epoch   500, train loss 0.148925, train error 4.18,  test loss 6.059019, test error 57.70
# Epoch   600, train loss 0.117112, train error 3.53,  test loss 7.194037, test error 57.25
# Epoch   700, train loss 0.228230, train error 7.47,  test loss 8.430283, test error 58.08
# Epoch   800, train loss 0.009317, train error 0.00,  test loss 9.130683, test error 57.45
# Epoch   900, train loss 0.006209, train error 0.00,  test loss 9.702980, test error 57.40
# Training model with  50 hidden variables
# Epoch     0, train loss 2.074942, train error 77.65,  test loss 2.015087, test error 76.82
# Epoch   100, train loss 0.730163, train error 22.60,  test loss 1.594781, test error 50.55
# Epoch   200, train loss 0.382669, train error 11.65,  test loss 2.588216, test error 54.12
# Epoch   300, train loss 0.172613, train error 4.03,  test loss 4.116859, test error 55.85
# Epoch   400, train loss 0.042960, train error 0.05,  test loss 5.761907, test error 57.28
# Epoch   500, train loss 0.017634, train error 0.03,  test loss 6.931385, test error 56.92
# Epoch   600, train loss 0.010093, train error 0.00,  test loss 7.668811, test error 56.75
# Epoch   700, train loss 0.006918, train error 0.00,  test loss 8.206201, test error 56.65
# Epoch   800, train loss 0.005274, train error 0.00,  test loss 8.638844, test error 56.75
# Epoch   900, train loss 0.004201, train error 0.00,  test loss 8.987253, test error 56.72
# Training model with  55 hidden variables
# Epoch     0, train loss 2.034033, train error 75.35,  test loss 1.976098, test error 75.12
# Epoch   100, train loss 0.598615, train error 17.88,  test loss 1.757167, test error 52.62
# Epoch   200, train loss 0.190484, train error 3.80,  test loss 3.254579, test error 55.30
# Epoch   300, train loss 0.034055, train error 0.00,  test loss 4.985277, test error 55.80
# Epoch   400, train loss 0.013019, train error 0.00,  test loss 5.951501, test error 55.58
# Epoch   500, train loss 0.007899, train error 0.00,  test loss 6.555591, test error 55.58
# Epoch   600, train loss 0.005493, train error 0.00,  test loss 6.995201, test error 55.60
# Epoch   700, train loss 0.004188, train error 0.00,  test loss 7.340520, test error 55.67
# Epoch   800, train loss 0.003310, train error 0.00,  test loss 7.621153, test error 55.70
# Epoch   900, train loss 0.002747, train error 0.00,  test loss 7.863308, test error 55.72
# Training model with  60 hidden variables
# Epoch     0, train loss 2.068742, train error 76.38,  test loss 2.048331, test error 76.97
# Epoch   100, train loss 0.528557, train error 14.40,  test loss 1.774783, test error 51.12
# Epoch   200, train loss 0.110028, train error 1.03,  test loss 3.488779, test error 54.53
# Epoch   300, train loss 0.019854, train error 0.00,  test loss 4.938559, test error 55.38
# Epoch   400, train loss 0.009667, train error 0.00,  test loss 5.669139, test error 55.30
# Epoch   500, train loss 0.006062, train error 0.00,  test loss 6.150502, test error 55.35
# Epoch   600, train loss 0.004358, train error 0.00,  test loss 6.505819, test error 55.40
# Epoch   700, train loss 0.003332, train error 0.00,  test loss 6.780306, test error 55.58
# Epoch   800, train loss 0.002684, train error 0.00,  test loss 7.013937, test error 55.47
# Epoch   900, train loss 0.002229, train error 0.00,  test loss 7.209221, test error 55.60
# Training model with  70 hidden variables
# Epoch     0, train loss 2.052227, train error 75.90,  test loss 2.004628, test error 75.28
# Epoch   100, train loss 0.382636, train error 10.22,  test loss 1.912415, test error 51.50
# Epoch   200, train loss 0.032596, train error 0.00,  test loss 3.596164, test error 53.25
# Epoch   300, train loss 0.011046, train error 0.00,  test loss 4.394326, test error 53.40
# Epoch   400, train loss 0.006121, train error 0.00,  test loss 4.845922, test error 53.30
# Epoch   500, train loss 0.004138, train error 0.00,  test loss 5.154132, test error 53.35
# Epoch   600, train loss 0.003050, train error 0.00,  test loss 5.395439, test error 53.40
# Epoch   700, train loss 0.002394, train error 0.00,  test loss 5.587162, test error 53.58
# Epoch   800, train loss 0.001955, train error 0.00,  test loss 5.744877, test error 53.60
# Epoch   900, train loss 0.001644, train error 0.00,  test loss 5.883279, test error 53.62
# Training model with  80 hidden variables
# Epoch     0, train loss 1.992743, train error 74.03,  test loss 1.943729, test error 74.45
# Epoch   100, train loss 0.234836, train error 4.38,  test loss 2.035448, test error 50.62
# Epoch   200, train loss 0.019646, train error 0.00,  test loss 3.404722, test error 52.58
# Epoch   300, train loss 0.008021, train error 0.00,  test loss 3.961456, test error 52.80
# Epoch   400, train loss 0.004739, train error 0.00,  test loss 4.290665, test error 53.05
# Epoch   500, train loss 0.003283, train error 0.00,  test loss 4.526260, test error 52.97
# Epoch   600, train loss 0.002470, train error 0.00,  test loss 4.709826, test error 53.08
# Epoch   700, train loss 0.001962, train error 0.00,  test loss 4.859735, test error 53.33
# Epoch   800, train loss 0.001615, train error 0.00,  test loss 4.986660, test error 53.38
# Epoch   900, train loss 0.001365, train error 0.00,  test loss 5.096034, test error 53.30
# Training model with  90 hidden variables
# Epoch     0, train loss 1.993139, train error 72.93,  test loss 1.938873, test error 74.18
# Epoch   100, train loss 0.143650, train error 1.05,  test loss 2.156919, test error 51.12
# Epoch   200, train loss 0.015161, train error 0.00,  test loss 3.231480, test error 51.75
# Epoch   300, train loss 0.006690, train error 0.00,  test loss 3.672053, test error 51.60
# Epoch   400, train loss 0.004063, train error 0.00,  test loss 3.941830, test error 51.75
# Epoch   500, train loss 0.002849, train error 0.00,  test loss 4.140537, test error 51.58
# Epoch   600, train loss 0.002167, train error 0.00,  test loss 4.293166, test error 51.55
# Epoch   700, train loss 0.001730, train error 0.00,  test loss 4.415576, test error 51.67
# Epoch   800, train loss 0.001432, train error 0.00,  test loss 4.520145, test error 51.55
# Epoch   900, train loss 0.001216, train error 0.00,  test loss 4.610465, test error 51.58
# Training model with 100 hidden variables
# Epoch     0, train loss 1.967601, train error 73.12,  test loss 1.902089, test error 74.28
# Epoch   100, train loss 0.098737, train error 0.43,  test loss 2.217683, test error 50.25
# Epoch   200, train loss 0.012422, train error 0.00,  test loss 3.082809, test error 50.42
# Epoch   300, train loss 0.005726, train error 0.00,  test loss 3.443109, test error 50.55
# Epoch   400, train loss 0.003567, train error 0.00,  test loss 3.671664, test error 50.20
# Epoch   500, train loss 0.002531, train error 0.00,  test loss 3.837953, test error 50.28
# Epoch   600, train loss 0.001940, train error 0.00,  test loss 3.968874, test error 50.17
# Epoch   700, train loss 0.001558, train error 0.00,  test loss 4.077581, test error 50.20
# Epoch   800, train loss 0.001296, train error 0.00,  test loss 4.169883, test error 50.17
# Epoch   900, train loss 0.001102, train error 0.00,  test loss 4.249103, test error 50.17
# Training model with 120 hidden variables
# Epoch     0, train loss 1.990008, train error 73.12,  test loss 1.952286, test error 73.60
# Epoch   100, train loss 0.053092, train error 0.00,  test loss 2.216206, test error 49.50
# Epoch   200, train loss 0.009646, train error 0.00,  test loss 2.873099, test error 49.90
# Epoch   300, train loss 0.004765, train error 0.00,  test loss 3.165997, test error 49.90
# Epoch   400, train loss 0.003029, train error 0.00,  test loss 3.351287, test error 50.00
# Epoch   500, train loss 0.002181, train error 0.00,  test loss 3.491001, test error 50.05
# Epoch   600, train loss 0.001685, train error 0.00,  test loss 3.600296, test error 49.97
# Epoch   700, train loss 0.001361, train error 0.00,  test loss 3.690319, test error 50.15
# Epoch   800, train loss 0.001136, train error 0.00,  test loss 3.767682, test error 50.10
# Epoch   900, train loss 0.000970, train error 0.00,  test loss 3.835241, test error 50.20
# Training model with 140 hidden variables
# Epoch     0, train loss 1.975025, train error 72.68,  test loss 1.901890, test error 73.40
# Epoch   100, train loss 0.035561, train error 0.00,  test loss 2.234442, test error 50.00
# Epoch   200, train loss 0.008076, train error 0.00,  test loss 2.749668, test error 50.12
# Epoch   300, train loss 0.004137, train error 0.00,  test loss 2.990890, test error 50.12
# Epoch   400, train loss 0.002692, train error 0.00,  test loss 3.147146, test error 50.17
# Epoch   500, train loss 0.001957, train error 0.00,  test loss 3.266325, test error 50.22
# Epoch   600, train loss 0.001522, train error 0.00,  test loss 3.358892, test error 50.00
# Epoch   700, train loss 0.001236, train error 0.00,  test loss 3.436433, test error 50.10
# Epoch   800, train loss 0.001034, train error 0.00,  test loss 3.502644, test error 50.00
# Epoch   900, train loss 0.000886, train error 0.00,  test loss 3.560374, test error 49.95
# Training model with 160 hidden variables
# Epoch     0, train loss 1.919490, train error 71.40,  test loss 1.867133, test error 72.90
# Epoch   100, train loss 0.027652, train error 0.00,  test loss 2.068086, test error 48.30
# Epoch   200, train loss 0.007071, train error 0.00,  test loss 2.466685, test error 48.22
# Epoch   300, train loss 0.003725, train error 0.00,  test loss 2.663873, test error 47.97
# Epoch   400, train loss 0.002450, train error 0.00,  test loss 2.794568, test error 47.95
# Epoch   500, train loss 0.001795, train error 0.00,  test loss 2.892930, test error 48.03
# Epoch   600, train loss 0.001402, train error 0.00,  test loss 2.970656, test error 48.10
# Epoch   700, train loss 0.001142, train error 0.00,  test loss 3.036018, test error 48.17
# Epoch   800, train loss 0.000959, train error 0.00,  test loss 3.091436, test error 48.35
# Epoch   900, train loss 0.000824, train error 0.00,  test loss 3.140065, test error 48.30
# Training model with 180 hidden variables
# Epoch     0, train loss 1.926058, train error 70.70,  test loss 1.866184, test error 72.43
# Epoch   100, train loss 0.024108, train error 0.00,  test loss 2.068101, test error 48.62
# Epoch   200, train loss 0.006487, train error 0.00,  test loss 2.418653, test error 48.55
# Epoch   300, train loss 0.003483, train error 0.00,  test loss 2.597072, test error 48.55
# Epoch   400, train loss 0.002310, train error 0.00,  test loss 2.716607, test error 48.40
# Epoch   500, train loss 0.001699, train error 0.00,  test loss 2.806646, test error 48.33
# Epoch   600, train loss 0.001332, train error 0.00,  test loss 2.879546, test error 48.35
# Epoch   700, train loss 0.001088, train error 0.00,  test loss 2.939984, test error 48.42
# Epoch   800, train loss 0.000915, train error 0.00,  test loss 2.992551, test error 48.33
# Epoch   900, train loss 0.000787, train error 0.00,  test loss 3.037748, test error 48.25
# Training model with 200 hidden variables
# Epoch     0, train loss 1.905503, train error 68.70,  test loss 1.805534, test error 70.53
# Epoch   100, train loss 0.021090, train error 0.00,  test loss 1.987040, test error 47.53
# Epoch   200, train loss 0.006119, train error 0.00,  test loss 2.301766, test error 47.60
# Epoch   300, train loss 0.003321, train error 0.00,  test loss 2.460234, test error 47.78
# Epoch   400, train loss 0.002212, train error 0.00,  test loss 2.567470, test error 47.88
# Epoch   500, train loss 0.001634, train error 0.00,  test loss 2.650155, test error 47.95
# Epoch   600, train loss 0.001283, train error 0.00,  test loss 2.715570, test error 47.78
# Epoch   700, train loss 0.001049, train error 0.00,  test loss 2.771441, test error 47.80
# Epoch   800, train loss 0.000883, train error 0.00,  test loss 2.818040, test error 47.78
# Epoch   900, train loss 0.000760, train error 0.00,  test loss 2.860186, test error 47.78
# Training model with 250 hidden variables
# Epoch     0, train loss 1.893468, train error 70.00,  test loss 1.829601, test error 71.60
# Epoch   100, train loss 0.016983, train error 0.00,  test loss 1.893141, test error 47.03
# Epoch   200, train loss 0.005307, train error 0.00,  test loss 2.136907, test error 47.00
# Epoch   300, train loss 0.002956, train error 0.00,  test loss 2.265189, test error 46.88
# Epoch   400, train loss 0.001996, train error 0.00,  test loss 2.353990, test error 47.03
# Epoch   500, train loss 0.001486, train error 0.00,  test loss 2.420310, test error 47.15
# Epoch   600, train loss 0.001173, train error 0.00,  test loss 2.474694, test error 47.15
# Epoch   700, train loss 0.000963, train error 0.00,  test loss 2.519756, test error 47.03
# Epoch   800, train loss 0.000813, train error 0.00,  test loss 2.558539, test error 46.97
# Epoch   900, train loss 0.000702, train error 0.00,  test loss 2.592703, test error 47.00
# Training model with 300 hidden variables
# Epoch     0, train loss 1.874902, train error 67.68,  test loss 1.796686, test error 70.72
# Epoch   100, train loss 0.014623, train error 0.00,  test loss 1.909259, test error 47.20
# Epoch   200, train loss 0.004836, train error 0.00,  test loss 2.134840, test error 47.33
# Epoch   300, train loss 0.002739, train error 0.00,  test loss 2.258920, test error 47.33
# Epoch   400, train loss 0.001866, train error 0.00,  test loss 2.342999, test error 47.33
# Epoch   500, train loss 0.001397, train error 0.00,  test loss 2.407784, test error 47.20
# Epoch   600, train loss 0.001106, train error 0.00,  test loss 2.458850, test error 47.33
# Epoch   700, train loss 0.000911, train error 0.00,  test loss 2.502306, test error 47.35
# Epoch   800, train loss 0.000771, train error 0.00,  test loss 2.540724, test error 47.22
# Epoch   900, train loss 0.000667, train error 0.00,  test loss 2.573618, test error 47.22
# Training model with 400 hidden variables
# Epoch     0, train loss 1.850915, train error 66.80,  test loss 1.811573, test error 70.18
# Epoch   100, train loss 0.011910, train error 0.00,  test loss 1.840192, test error 46.65
# Epoch   200, train loss 0.004222, train error 0.00,  test loss 2.027248, test error 46.38
# Epoch   300, train loss 0.002444, train error 0.00,  test loss 2.131955, test error 46.38
# Epoch   400, train loss 0.001683, train error 0.00,  test loss 2.204986, test error 46.25
# Epoch   500, train loss 0.001268, train error 0.00,  test loss 2.260525, test error 46.40
# Epoch   600, train loss 0.001009, train error 0.00,  test loss 2.305424, test error 46.50
# Epoch   700, train loss 0.000834, train error 0.00,  test loss 2.343030, test error 46.47
# Epoch   800, train loss 0.000707, train error 0.00,  test loss 2.375919, test error 46.45
# Epoch   900, train loss 0.000613, train error 0.00,  test loss 2.404423, test error 46.50

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
